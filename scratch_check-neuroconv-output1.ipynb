# %%
from pynwb import NWBHDF5IO
import os

# %%
nwb_path = '.'
fname = 'test_neuroconv1.nwb'
io = NWBHDF5IO(os.path.join(nwb_path,fname), mode="r") # <-- open in write to append snippets?
nwbfile = io.read()

# %%
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x2474666634896
# Fields:
#   acquisition: {
#     dms_calcium_signal <class 'abc.FiberPhotometryResponseSeries'>
#   }
#   devices: {
#     dichroic_mirror <class 'abc.DichroicMirror'>,
#     dms_green_fluorophore <class 'abc.Indicator'>,
#     excitation_source_calcium_signal <class 'abc.ExcitationSource'>,
#     excitation_source_red_control_signal <class 'abc.ExcitationSource'>,
#     optical_fiber <class 'abc.OpticalFiber'>,
#     photodetector <class 'abc.Photodetector'>
#   }
#   file_create_date: [datetime.datetime(2025, 10, 20, 16, 32, 20, 457669, tzinfo=tzoffset(None, -25200))]
#   identifier: 9ce5a564-4c03-491a-8d51-3db857bac36c
#   lab_meta_data: {
#     fiber_photometry <class 'abc.FiberPhotometry'>
#   }
#   session_start_time: 2019-02-18 22:25:50.999999+00:00
#   source_script: Created using NeuroConv v0.8.1
#   source_script_file_name: C:\Users\Nerissa\anaconda3\envs\neuroconv\Lib\site-packages\neuroconv\basedatainterface.py
#   timestamps_reference_time: 2019-02-18 22:25:50.999999+00:00

# %%
io.close()

# %%
nwb_path = '.'
fname = 'test_neuroconv2.nwb'
io = NWBHDF5IO(os.path.join(nwb_path,fname), mode="r") # <-- open in write to append snippets?
nwbfile = io.read()
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x2474699525872
# Fields:
#   acquisition: {
#     calcium_signal <class 'abc.FiberPhotometryResponseSeries'>
#   }
#   devices: {
#     NAcc_GCaMP_injection <class 'abc.Indicator'>,
#     NAcc_tdTomato_injection <class 'abc.Indicator'>,
#     dichroic_mirror <class 'abc.DichroicMirror'>,
#     excitation_source_calcium_signal <class 'abc.ExcitationSource'>,
#     excitation_source_red_control_signal <class 'abc.ExcitationSource'>,
#     optical_fiber <class 'abc.OpticalFiber'>,
#     photodetector_green <class 'abc.Photodetector'>,
#     photodetector_red <class 'abc.Photodetector'>
#   }
#   file_create_date: [datetime.datetime(2025, 10, 21, 10, 50, 22, 62496, tzinfo=tzoffset(None, -25200))]
#   identifier: 4bc62591-8092-4f7d-a8ea-d05fe87223f2
#   lab_meta_data: {
#     fiber_photometry <class 'abc.FiberPhotometry'>
#   }
#   session_start_time: 2019-02-18 22:25:50.999999+00:00
#   source_script: Created using NeuroConv v0.8.1
#   source_script_file_name: C:\Users\Nerissa\anaconda3\envs\neuroconv\Lib\site-packages\neuroconv\basedatainterface.py
#   timestamps_reference_time: 2019-02-18 22:25:50.999999+00:00

# %%
test = nwbfile.acquisition['calcium_signal'].data[3,0:10]
print(test)
# Out:
# [ 1.1596857e-02  7.0191501e-03 -4.6566129e-09 -2.7466286e-03
#   2.7466239e-03 -5.7984330e-03  3.0518044e-04 -3.0518090e-03
#   4.2725261e-03 -7.9346960e-03]

# %%
for k, v in nwbfile.acquisition.items():
    print(
        "name=%s, chunks=%s, compression=%s, maxshape=%s"
        % (k, v.data.chunks, v.data.compression, v.data.maxshape)
    )
# Out:
# name=calcium_signal, chunks=(4, 1581), compression=gzip, maxshape=(4, 18565120)
